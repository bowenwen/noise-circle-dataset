# %% [markdown]
# ![Toronto AI](https://i.imgur.com/diILtDP.png)

# %% [markdown]
# # Neural Networks
#
# A trained neural net can be thought of as a learned mapping.
#
# Here are some examples of mappings that a neural net could learn:
#
# *   Mapping English to French
# *   Mapping pictures to text descriptions
# *   Mapping live sensor data from a reusable rocket to control commands that land it
# *   Mapping random vectors into images of flowers
#
# In essence, we use neural nets to map one distribution of data onto another.
#
# Here's an an example where I trained a neural net to map random vectors onto the space of flower photos, using a Generative Adversarial Network:
#
# ![](https://i.imgur.com/SaT9OEM.png)

# %% [markdown]
# # Tensors
#
# * Tensors are multidimensional arrays.
# * They are like boxes of data, that we use to contain our data, or the weights of our model.
# * Tensors are used extensively in TensorFlow to represent:
#   * 0-D - scalars
#   * 1-D - vectors, text
#   * 2-D - matrices, tables of data
#   * 3-D - batches of matrices, a cube of data, e.g. an image, a monochrome video
#   * 4-D - convolution kernels, a colour video
#   * 5-D - batches of colour video
#   * 6-D - 3D vector fields
#   * 7-D - layered 3D vector fields (e.g. gravity and electromagnetism layers)
#   * 8-D - batches of layered 3D vector fields
#   * 9-D - batches of layered 3D vector fields evolving through time
#   * keep going...
#
# * GPU memory is expensive, so Tensors are most commonly 4-D or less.
#
# * It helps to visualize a Tensor as a Rubiks Cube - each cell holds a piece of scalar data (like a weight, a piece of input data, or a label).  For higher dimensional Tensors, think of each cell as holding a Tensor instead of a scalar.
# ![](https://i.imgur.com/KyOQVX9.png)

# %%
import tensorflow as tf
import os

DIRECTORY = os.path.join("~", "ai")
# Out:
# D:\Users\bowen\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Synthetic Dataset

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import random, math
from matplotlib import animation, rc
from IPython.display import HTML

plt.rcParams['image.cmap'] = 'viridis'

np.random.seed(20180118)

BATCH_SIZE = 16
DIM = 64
TWO_PI = 2.*math.pi
MIN_CIRCLE_WIDTH = int(DIM/10)
NUM_CIRCLE_DOTS = 500
CIRCLE_WIDTH = 3
DARKNESS = .5

# We'll use this to create our data set.
def add_circles(data):
    radius = int((random.random() * (DIM/2 - MIN_CIRCLE_WIDTH)) + MIN_CIRCLE_WIDTH)
    xpos = random.random()*DIM
    ypos = random.random()*DIM
    
    draw_circle(data, xpos, ypos, radius, DARKNESS, CIRCLE_WIDTH)

    return [xpos, ypos, radius+CIRCLE_WIDTH/2]


def draw_circle(data, xpos, ypos, radius, darkness, width):
    for i in range(NUM_CIRCLE_DOTS):
        for r in range(radius, radius+width):
            rad = TWO_PI * i/NUM_CIRCLE_DOTS
            x = int(round(r*math.cos(rad)+xpos))
            y = int(round(-r*math.sin(rad)+ypos))
            if x >= 0 and x < DIM and y >= 0 and y < DIM:
                data[x,y] = data[x,y] - darkness


            
# Create random noise and draw circles in it
def create_dataset_row():
    data = np.random.random((DIM, DIM)).astype(np.float32)
    label = add_circles(data)
    label = np.array(label).astype(np.float32)
    
    return (data, label)
    

def create_dataset(rows):
    
    labels  = []
    samples = []
    for i in range(rows):
        data, label = create_dataset_row()
        labels.append(label)
        samples.append(data)
    return (np.array(samples).astype(np.float32), np.array(labels).astype(np.float32))

        

# Create an animation so we can see our data set
dataset = create_dataset(BATCH_SIZE)
data   = dataset[0]
labels = dataset[1]


def plot_dataset(data):
    fig, ax = plt.subplots()

    def init():
        ax.cla()
        return ()

    def animate(i):
        ax.imshow(data[i%len(data)])
        return ()

    anim = animation.FuncAnimation(fig, animate, init_func=init, frames=BATCH_SIZE, interval=700, blit=True)
    plt.close(fig)
    fig.set_size_inches(10, 10, True)
    return HTML(anim.to_jshtml())


    
plot_dataset(data)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgaa5e0ead4e8e4f3da289b823110d212b">
#     <br>
#     <input id="_anim_slideraa5e0ead4e8e4f3da289b823110d212b" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animaa5e0ead4e8e4f3da289b823110d212b.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animaa5e0ead4e8e4f3da289b823110d212b.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animaa5e0ead4e8e4f3da289b823110d212b.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animaa5e0ead4e8e4f3da289b823110d212b.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animaa5e0ead4e8e4f3da289b823110d212b.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animaa5e0ead4e8e4f3da289b823110d212b.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animaa5e0ead4e8e4f3da289b823110d212b.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animaa5e0ead4e8e4f3da289b823110d212b.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animaa5e0ead4e8e4f3da289b823110d212b.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animaa5e0ead4e8e4f3da289b823110d212b.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectaa5e0ead4e8e4f3da289b823110d212b" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgaa5e0ead4e8e4f3da289b823110d212b";
#     var slider_id = "_anim_slideraa5e0ead4e8e4f3da289b823110d212b";
#     var loop_select_id = "_anim_loop_selectaa5e0ead4e8e4f3da289b823110d212b";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvNQv5yAAAIABJREFUeJzs3Xl81PW1x/8zmcxkMtkTsi+EVQFR\
# NqVuiAIuqKCVUq1W6lJ6r7Z16WLb621r259aW61r66WlLS61dQVEBYuI4oIYFURZDEggCdn3bZKZ\
# yfz+8NH7+90rOWc+CoU+7uv53/WdvjOZ+c43H+bCOZ5YLBYTAAAAAHFJONwPAAAAAPhXwgEaAAAA\
# cMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABw\
# wAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDA\
# ARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMAB\
# GgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEa\
# AAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoA\
# AABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAA\
# AHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAA\
# cMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABw\
# wAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDA\
# ARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMABGgAAAHDAARoAAABwwAEaAAAAcMAB\
# GgAAAHDAARoAAABwkHi4HwBE/JnJEixIGzL3xNFR6m9T896Yz+zweaJq3hUNmB19g341T/f2mR2p\
# Cf1q3hpNMTvyEnvVvGvQvvQTJKbmLZFUsyMrsUfNm8N2R4G/Q817B5PMjt6o/rp4PPrPKiKSnBBW\
# 84BnwOzoN65D6/oREQkm6N8nxbh+REQCHv1d1WM/HebrHzCeLxGRaEz/DCOe90tXNFnNUxJCZkfM\
# uMtkJNhPSHNUf20jcXxeE4vpjyMpjufUuk/5jfuciIjXM6jm6XE8pzUDmWruS7Afx6BxfZQZ9wYR\
# kYZIUM37jHuDiEhSQkTNQ3HcT5O9+mvnMe63IvZ737pni4i0RvTfH9bjFBFJT9Dfl/0x+/kIGffC\
# tDiusfqBDDW3rmMREWkSaW5utr8On8IB+hBZvXq1XHfddRKNRuXqq6+WH/zgB0N+bbAgTWb8fuGQ\
# eWIcN9q7hi9X8839eWZHcWK7mq/tnmB2bO0qVvMzsz8wO05NrlLzRzummR3fyn5PzV/uyzU7gh79\
# IPZQ48lmx8LcTWr+5zq74/slq9X8nVC52bG5q0zNE+K40R6Tsl/NxwdqzI7dA/lq/kGPfv2IiByX\
# Uq3mX0jeY3aM9emHhk399h9bH205Sf8ewXqzo834ZX5m2laz45XucWo+PWWX2RE2fuGfHbT/ULK0\
# o0DN4/mDb/+gfqgYG6gzO9Z36M9HSZL+YYOISIbxB/A5KTvMju9XfVHNi4L24bczrP9h4MEy/d4g\
# InJnyxQ139pZZHaMSGlR851d+vtaROSYdP3+YR3SRUQmB6vUPOCxD79/a56u5hNS9ccpInJOqv57\
# bGfY/n1b2a8/Z2ekbDc7bquZq+ZpPvt9++E175tfgwPjr3AcAtFoVK699lp54YUXZ

# %% [markdown]
# # GOALS
#
# * Predict the radius of the circle
# * Predict the center of the circle
#
# We are going to create a neural net to solve this problem for us, since it would be very difficult to solve this with conventional code.

# %% [markdown]
# ![](https://i.imgur.com/o2qIsu4.png)

# %% [markdown]
# # Convolutional Layers
#
#
# * a convolutional layer is used to extract 'feature maps' from the previous layer.
# * feature maps are called 'channels' in TensorFlow.
# * Channels are familiar.  Images often have three feature maps: the Red, Green and Blue channels.
#
# * You can stack convolution layers.  Learn basic features from an image in one layer, then learn features of those features in the next layer.
#
# * Convolutional layers can be employed to learn dozens of feature maps off the data.
#
#
# ![](https://upload.wikimedia.org/wikipedia/commons/6/63/Typical_cnn.png)
# _Image credits: Aphex34 (Wikimedia Commons)_
#
#
#
#
#
# ### Convolutional layers learn feature maps, one for each filter.
# * Each filter acts like a small window through which it can read a specific feature from each channel of the input.
# * Each filter passes across the entire image and at each position combines the features detected in the input channels into an output channel.
# * A convolutional layer with many filters will have an output channel for each filter, holding the results.

# %%
# docs: https://www.tensorflow.org/api_docs/python/tf/layers/conv2d

def Convolution(layer, name, num_filters, size=3, activation=tf.nn.relu): 

    with tf.variable_scope("detector", reuse=tf.AUTO_REUSE):
        
        layer = tf.layers.conv2d( 
              name=name, 
              inputs=layer,
              kernel_size=size,
              filters=num_filters,
              padding='same',
              activation=activation # the activation function used: nonlinearity gets applied
        )
        return layer

# %% [markdown]
# ### Activation functions
# * To add 'depth' to our convolutional layer (i.e. the depth in deep learning), we need to add a non-linearity to the output, called an activation function.
# * We'll use a Leaky ReLu (Rectified Linear Unit) - it's nonlinear and simple.  ELUs are a great choice as well.
#
# <table>
#     <tr>
#         <th>tf.nn.leaky_relu</th><td><img src="https://i.imgur.com/KxYFRIL.png =100x100" alt="Drawing" style="width: 200px;"/>
#         </td>
#     </tr>
#     <tr><th>Other activation functions</th><td>
#         <p><code>tf.nn.relu</code> <i>(dense, convolution)</i></p>
#             <p><code>tf.nn.elu</code> <i>(dense, convolution)</i></p>
#             <p><code>tf.nn.softplus</code> <i>(dense, convolution)</i></p>
#             <p><code>tf.nn.sigmoid</code> <i>(0 to 1 classifier)</i></p>
#             <p><code>tf.nn.tanh</code> <i>(LSTM, -1 to 1 classifier)</i></p>
#     </td>
#     </tr>
# </table>
#
# <table>
#         <th>other functions</th><td><img src="https://4.bp.blogspot.com/-4puZ_ZMyoLE/WPk_rwqhKnI/AAAAAAAAAjU/vrNE_Uv54yMLOd_3E83PvgpByf019ufZwCLcB/s1600/ActivationFunctions.png =200x200" alt="Drawing" style="width: 400px;"/>
#         </td>
# </table>
#
# </br>
# Dense means dense layers or fully connected layers
# </br>
# For image recognitions, relu and leaky relu are good options.
# </br>
# Further reading on activation functions:
# * https://en.wikipedia.org/wiki/Rectifier_(neural_networks) - Overview of Retifiers in neural nets
# * https://arxiv.org/abs/1505.00853 - Empirical Evaluation of Rectified Activations in Convolutional Network
# * https://arxiv.org/abs/1709.06247 - Training Better CNNs Requires to Rethink ReLU

# %% [markdown]
# # Pooling
#
# * Shrink a layer
# * Using a stride of two will halve the width and height.
# * The pool_size should be at least as large as the strides

# %%
def AvgPooling(layer): 
    return tf.layers.average_pooling2d(layer, pool_size=(2,2), strides=(2,2))

def MaxPooling(layer): 
    return tf.layers.max_pooling2d(layer, pool_size=(2,2), strides=(2,2))

# %% [markdown]
# # Creating our graph
#
# ## Subgraph: The convolutional layers
#
# * We are stacking our convolutional layers, so that later layers detect features on lower layers.
# * Higher layers learn higher level features from lower layers that learn lower level features.

# %%
def convolutional_layers(batch):
    
    layer = tf.reshape(batch, [BATCH_SIZE, DIM, DIM, 1])  # We need a channel dimension, adding one here.
    
    with tf.variable_scope("convolutional"):
        
        FS = 32 # maximum features
        K  = 7  # kernel size
        
        layer = Convolution(layer, "A1", num_filters=FS, size=K)
        layer = Convolution(layer, "A2", num_filters=FS, size=K)
        layer = Convolution(layer, "A3", num_filters=FS, size=K)

        layer = AvgPooling(Convolution(layer, "A4", num_filters=FS, size=K))
        layer = AvgPooling(Convolution(layer, "A5", num_filters=FS, size=K))
        layer = AvgPooling(Convolution(layer, "A6", num_filters=FS, size=K))

        
#         layer =  AvgPooling(layer)
#         layer = Convolution(layer, "L4", num_filters=FS, size=5)
        
#         layer =  AvgPooling(layer)
#         layer = Convolution(layer, "L5", num_filters=FS, size=3)
        
        return layer

# %% [markdown]
# After our image goes through the convolutional layer, we still need to do some inference through the dense layers.

# %% [markdown]
# ## Subgraph: The fully connected dense layers
#
# * These layers are used to convert the tensor that was output from the convolutional layers down into a prediction.
# * In our case, we want 3 outputs
#
#   * The X and Y coordinate of the center of the circle
#   * The radius of the circle
#
# * Here we're dividing the channels into thirds, and we have attached one subnet of fully connected layers to each output.
# * We are asking the neural net that the sum of the outputs of each subnet is the corresponding prediction (for x, y, radius)

# %%
def dense_layers(layer): 
    
    layer = tf.reshape(layer, [BATCH_SIZE, -1])    # Make it a table, one row for each example in the batch.
    # -1 specifies taking all of the data
    
    x_guess = add_subnet(layer, 0)  # Let's create a subnet for predicting the X coordinate,
    y_guess = add_subnet(layer, 1)  # A subnet for the y coordinate,
    r_guess = add_subnet(layer, 2)  # and, a subnet for predicting the radius
    
    y_guess2 = add_subnet(layer, 1)  # A subnet for the y coordinate,
    
    return x_guess, (y_guess+y_guess2)/2., r_guess




def add_subnet(layer, i):
    ROW_DIM = 1
    a_third  = int(layer.shape[ROW_DIM].value / 3)
    
    # taking a third of the data
    layer = tf.slice(layer, [0, i*a_third], [BATCH_SIZE, a_third])
    
    
    layer = tf.layers.dense(layer, 32,  activation=tf.nn.elu) # 32 layers of neurons to pass through
    layer = tf.layers.dense(layer, 32,  activation=tf.nn.elu) # then into the next 32 layers of neurons to pass through
    layer = tf.layers.dense(layer, 32,  activation=tf.nn.elu)
    # layer size: 32x32x32

    # Return the sum of the last layer as our prediction
    return tf.reduce_sum(layer, axis=[1])

# %% [markdown]
# # Objective function (a.k.a. the loss function)
#
# * The objective function is what the system attempts to minimize
# * The most important thing to remember is that the loss function needs to be differentiable with a minimum value at your goal.
# * Convex functions are easy to minimize.
#
# ### Common objectives
# * Minimizing the difference of squares (a.k.a. mean squared error)
#
# * Minimizing the log loss - this is useful in classification tasks when dealing with probabilities.

# %%
# keep this differentiable: smooth (not bumpy) so derivatives can be easily computed

def loss_function(x, y, r, labels):

    
    actual_x, actual_y, actual_r = labels[:,0], labels[:,1], labels[:,2]
    
    
    # Define an error between the predicted x, y and radius, and their actual values
    # We will later ask the network to minimize this error through gradient descent
    
    x_error = tf.pow(x - actual_x, 2.)
    # x_error = tf.square(x - actual_x, 2.)
    y_error = tf.pow(y - actual_y, 2.)
    r_error = tf.pow(r - actual_r, 2.)

    
    # Let's combine these individual loss metrics into a combined loss function
    # Note: these are vectors - with separate losses defined for each element in the batch     
    # reduce the difference between predictive value and actual value with gradient descent
    loss = x_error + y_error + r_error

    # Now lets create some metrics that we can use to evaluate our progress
    avg_distance_from_actual_center = tf.reduce_mean(tf.sqrt(x_error + y_error))
    avg_radius_error = tf.reduce_mean(r_error)
    
    tf.summary.scalar("avg_distance_from_actual_center", avg_distance_from_actual_center)
    tf.summary.scalar("avg_radius_error",                avg_radius_error)
    
    return {
        "combined" : loss,
        "center_error_px" : avg_distance_from_actual_center,
        "radius_error_px" : avg_radius_error
    }

# %% [markdown]
# # Optimizer
#
# There are many choices for optimizers.
# For most applications, the Adam optimizer will give you good flexibility and fast training.
#
# ## Adam
#
# * Currently the most popular optimizer
#
# * The adam optimizer is a gradient descent optimization alogirthm that adds two things:
#   * First, it adds momentum to each weight of your model to help it descend.
#   * Second, it slows down weights proportionally to how much they are oscillating (variance)
#
# * Both of the effects of the Adam optimizer have an exponential decay built in.  These are parameters to the optimizer.
#   * alpha - The learning rate.  Typical values are 0.0003 to to 0.000003
#   * beta1 - The decay rate of the momentum term.  Typical values are 0.5 to 0.9.
#   * beta2 - The decay rate of the variance term.  Typical values are 0.9 to 0.999
#
#
#
# Further reading:
# * https://arxiv.org/abs/1412.6980 Adam: A Method for Stochastic Optimization
# * http://ruder.io/optimizing-gradient-descent/ An overview of gradient descent optimization algorithms

# %%
ALPHA = 0.0001
BETA1 = 0.5
BETA2 = 0.9


def add_optimizer(loss):
    
    opt      = tf.train.AdamOptimizer(learning_rate = ALPHA, beta1=BETA1, beta2=BETA2)
    train_op = opt.minimize(loss=loss) # ask the optimizer to minimize the loss
    return train_op

# %% [markdown]
# # Connecting the model pieces together

# %%
def create_model(samples, labels):

    x, y, r = dense_layers( convolutional_layers( samples ) ) # connect to dense layers

    losses = loss_function(x, y, r, labels)

    training_op = add_optimizer(losses["combined"])

    return {
        "training_op"   : training_op,
        "losses"          : losses,
        "samples"       : samples,
        "prediction"    : (x, y, r),
        "actual"        : labels
    }

# %% [markdown]
# # Preparing a Training run

# %%
import itertools

tf.reset_default_graph()


def row_generator():
    for i in itertools.count(1):
        yield create_dataset_row()


# creating a data pipeline
def create_input_pipeline():
    # use the generator to generate dynamic dataset
    dataset = tf.data.Dataset.from_generator(row_generator,
                                             (tf.float32, tf.float32))
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.repeat()

    pipeline_iterator = dataset.make_initializable_iterator()

    return pipeline_iterator


latest_results = None


def run_session(session, run_name, num_iterations):
    global latest_results  # make this global so we don't have to finish the training to see the result!
    np.random.seed(20180118)
    ema_radius = 500
    ema_center = 500

    UPDATE_TENSORBOARD_PERIOD = 1

    #     with tf.device("/device:CPU:0"): # use GPU if you have it

    # https://www.tensorflow.org/programmers_guide/using_gpu
    with tf.device("/device:GPU:0"):  # use GPU if you have it
        # a file writer to write session
        fw = tf.summary.FileWriter(
            DIRECTORY + run_name, graph=session.graph, flush_secs=2)

        #
        pipeline = create_input_pipeline()

        sample_batch, labels_batch = pipeline.get_next()

        #
        model = create_model(sample_batch, labels_batch)

        #
        tf.global_variables_initializer().run()

        # initial the pipeline, create a session
        session.run(pipeline.initializer)

        # for each iteration, we run the sample batch to get a new batch
        for step in range(num_iterations):

            new_batch = session.run(sample_batch)

            # pieces being trained
            latest_results = session.run({
                "losses": model["losses"],
                "train_op": model["training_op"],
                "samples": model["samples"],
                "prediction": model["prediction"],
                "actual": model["actual"],
                "summary": tf.summary.merge_all()
            })

            # report radius error in pixels
            # use exponential moving average that keeps 90% of previous value, add 10% of new, super simple to implement
            stats = latest_results["losses"]
            ema_radius = ema_radius * .9 + .1 * stats["radius_error_px"]
            ema_center = ema_center * .9 + .1 * stats["center_error_px"]

            if step % UPDATE_TENSORBOARD_PERIOD == 0:
                print(
                    "step: {step}, EMA radius error: {ema_radius:.0f}px. EMA center error: {ema_center:.0f}px".
                    format(
                        step=step,
                        ema_radius=ema_radius,
                        ema_center=ema_center))
                fw.add_summary(latest_results["summary"], step)

        return latest_results

# %% [markdown]
# # Start Training!

# %%
tf.reset_default_graph()

# session = tf.Session()
# tensorflow gpu bug fix: https://github.com/tensorflow/tensorflow/issues/2285
config = tf.ConfigProto(allow_soft_placement = True)
session = tf.Session(config = config)

with session:

    latest_results = run_session(session, "1000steps", 1000)
#     latest_results = run_session(session, "100steps", 100)

print("Complete!")
# ResNet w 8 filters: step: 100, ema radius error: 71.01px. Avg center error: 16.13px
# Out:
# step: 0, EMA radius error: 494px. EMA center error: 455px
# step: 1, EMA radius error: 507px. EMA center error: 414px
# step: 2, EMA radius error: 500px. EMA center error: 378px
# step: 3, EMA radius error: 498px. EMA center error: 344px
# step: 4, EMA radius error: 497px. EMA center error: 315px
# step: 5, EMA radius error: 468px. EMA center error: 288px
# step: 6, EMA radius error: 450px. EMA center error: 263px
# step: 7, EMA radius error: 435px. EMA center error: 240px
# step: 8, EMA radius error: 415px. EMA center error: 219px
# step: 9, EMA radius error: 390px. EMA center error: 200px
# step: 10, EMA radius error: 357px. EMA center error: 183px
# step: 11, EMA radius error: 335px. EMA center error: 167px
# step: 12, EMA radius error: 315px. EMA center error: 152px
# step: 13, EMA radius error: 292px. EMA center error: 139px
# step: 14, EMA radius error: 268px. EMA center error: 128px
# step: 15, EMA radius error: 248px. EMA center error: 118px
# step: 16, EMA radius error: 229px. EMA center error: 109px
# step: 17, EMA radius error: 217px. EMA center error: 101px
# step: 18, EMA radius error: 205px. EMA center error: 93px
# step: 19, EMA radius error: 196px. EMA center error: 87px
# step: 20, EMA radius error: 186px. EMA center error: 80px
# step: 21, EMA radius error: 173px. EMA center error: 75px
# step: 22, EMA radius error: 163px. EMA center error: 70px
# step: 23, EMA radius error: 151px. EMA center error: 65px
# step: 24, EMA radius error: 142px. EMA center error: 61px
# step: 25, EMA radius error: 136px. EMA center error: 58px
# step: 26, EMA radius error: 128px. EMA center error: 54px
# step: 27, EMA radius error: 122px. EMA center error: 52px
# step: 28, EMA radius error: 118px. EMA center error: 49px
# step: 29, EMA radius error: 112px. EMA center error: 46px
# step: 30, EMA radius error: 107px. EMA center error: 43px
# step: 31, EMA radius error: 101px. EMA center error: 42px
# step: 32, EMA radius error: 97px. EMA center error: 40px
# step: 33, EMA radius error: 93px. EMA center error: 38px
# step: 34, EMA radius error: 90px. EMA center error: 37px
# step: 35, EMA radius error: 85px. EMA center error: 35px
# step: 36, EMA radius error: 82px. EMA center error: 34px
# step: 37, EMA radius error: 83px. EMA center error: 33px
# step: 38, EMA radius error: 80px. EMA center error: 32px
# step: 39, EMA radius error: 79px. EMA center error: 32px
# step: 40, EMA radius error: 79px. EMA center error: 30px
# step: 41, EMA radius error: 80px. EMA center error: 30px
# step: 42, EMA radius error: 79px. EMA center error: 29px
# step: 43, EMA radius error: 78px. EMA center error: 29px
# step: 44, EMA radius error: 78px. EMA center error: 28px
# step: 45, EMA radius error: 75px. EMA center error: 27px
# step: 46, EMA radius error: 78px. EMA center error: 27px
# step: 47, EMA radius error: 80px. EMA center error: 27px
# step: 48, EMA radius error: 77px. EMA center error: 27px
# step: 49, EMA radius error: 75px. EMA center error: 26px
# step: 50, EMA radius error: 75px. EMA center error: 26px
# step: 51, EMA radius error: 74px. EMA center error: 25px
# step: 52, EMA radius error: 73px. EMA center error: 25px
# step: 53, EMA radius error: 73px. EMA center error: 25px
# step: 54, EMA radius error: 71px. EMA center error: 24px
# step: 55, EMA radius error: 70px. EMA center error: 24px
# step: 56, EMA radius error: 74px. EMA center error: 24px
# step: 57, EMA radius error: 72px. EMA center error: 23px
# step: 58, EMA radius error: 72px. EMA center error: 23px
# step: 59, EMA radius error: 70px. EMA center error: 23px
# step: 60, EMA radius error: 67px. EMA center error: 22px
# step: 61, EMA radius error: 68px. EMA center error: 22px
# step: 62, EMA radius error: 68px. EMA center error: 22px
# step: 63, EMA radius error: 70px. EMA center error: 22px
# step: 64, EMA radius error: 70px. EMA center error: 22px
# step: 65, EMA radius error: 72px. EMA center error: 22px
# step: 66, EMA radius error: 72px. EMA center error: 22px
# step: 67, EMA radius error: 70px. EMA center error: 22px
# step: 68, EMA radius error: 74px. EMA center error: 22px
# step: 69, EMA radius error: 73px. EMA center error: 22px
# step: 70, EMA radius error: 73px. EMA center error: 22px
# step: 71, EMA radius error: 75px. EMA center error: 21px
# step: 72, EMA radius error: 76px. EMA center error: 21px
# step: 73, EMA radius error: 73px. EMA center error: 21px
# step: 74, EMA radius error: 71px. EMA center error: 20px
# step: 75, EMA radius error: 71px. EMA center error: 20px
# step: 76, EMA radius error: 72px. EMA center error: 20px
# step: 77, EMA radius error: 72px. EMA center error: 19px
# step: 78, EMA radius error: 70px. EMA center error: 19px
# step: 79, EMA radius error: 73px. EMA center error: 18px
# step: 80, EMA radius error: 70px. EMA center error: 18px
# step: 81, EMA radius error: 70px. EMA center error: 18px
# step: 82, EMA radius error: 68px. EMA center error: 18px
# step: 83, EMA radius error: 69px. EMA center error: 18px
# step: 84, EMA radius error: 66px. EMA center error: 18px
# step: 85, EMA radius error: 65px. EMA center error: 18px
# step: 86, EMA radius error: 66px. EMA center error: 17px
# step: 87, EMA radius error: 65px. EMA center error: 17px
# step: 88, EMA radius error: 64px. EMA center error: 17px
# step: 89, EMA radius error: 61px. EMA center error: 16px
# step: 90, EMA radius error: 60px. EMA center error: 16px
# step: 91, EMA radius error: 61px. EMA center error: 16px
# step: 92, EMA radius error: 65px. EMA center error: 16px
# step: 93, EMA radius error: 68px. EMA center error: 16px
# step: 94, EMA radius error: 65px. EMA center error: 16px
# step: 95, EMA radius error: 62px. EMA center error: 16px
# step: 96, EMA radius error: 62px. EMA center error: 16px
# step: 97, EMA radius error: 62px. EMA center error: 16px
# step: 98, EMA radius error: 60px. EMA center error: 16px
# step: 99, EMA radius error: 60px. EMA center error: 16px
# step: 100, EMA radius error: 58px. EMA center error: 16px
# step: 101, EMA radius error: 59px. EMA center error: 15px
# step: 102, EMA radius error: 60px. EMA center error: 15px
# step: 103, EMA radius error: 57px. EMA center error: 15px
# step: 104, EMA radius error: 56px. EMA center error: 15px
# step: 105, EMA radius error: 57px. EMA center error: 15px
# step: 106, EMA radius error: 58px. EMA center error: 15px
# step: 107, EMA radius error: 58px. EMA center error: 14px
# step: 108, EMA radius error: 56px. EMA center error: 15px
# step: 109, EMA radius error: 56px. EMA center error: 14px
# step: 110, EMA radius error: 60px. EMA center error: 14px
# step: 111, EMA radius error: 58px. EMA center error: 14px
# step: 112, EMA radius error: 60px. EMA center error: 14px
# step: 113, EMA radius error: 59px. EMA center error: 14px
# step: 114, EMA radius error: 60px. EMA center error: 14px
# step: 115, EMA radius error: 61px. EMA center error: 14px
# step: 116, EMA radius error: 60px. EMA center error: 15px
# step: 117, EMA radius error: 58px. EMA center error: 14px
# step: 118, EMA radius error: 58px. EMA center error: 15px
# step: 119, EMA radius error: 58px. EMA center error: 14px
# step: 120, EMA radius error: 57px. EMA center error: 14px
# step: 121, EMA radius error: 54px. EMA center error: 14px
# step: 122, EMA radius error: 53px. EMA center error: 14px
# step: 123, EMA radius error: 51px. EMA center error: 13px
# step: 124, EMA radius error: 50px. EMA center error: 13px
# step: 125, EMA radius error: 50px. EMA center error: 13px
# step: 126, EMA radius error: 49px. EMA center error: 13px
# step: 127, EMA radius error: 49px. EMA center error: 12px
# step: 128, EMA radius error: 48px. EMA center error: 13px
# step: 129, EMA radius error: 48px. EMA center error: 13px
# step: 130, EMA radius error: 46px. EMA center error: 13px
# step: 131, EMA radius error: 47px. EMA center error: 13px
# step: 132, EMA radius error: 46px. EMA center error: 13px
# step: 133, EMA radius error: 46px. EMA center error: 13px
# step: 134, EMA radius error: 47px. EMA center error: 13px
# step: 135, EMA radius error: 46px. EMA center error: 13px
# step: 136, EMA radius error: 43px. EMA center error: 13px
# step: 137, EMA radius error: 40px. EMA center error: 13px
# step: 138, EMA radius error: 42px. EMA center error: 13px
# step: 139, EMA radius error: 41px. EMA center error: 13px
# step: 140, EMA radius error: 40px. EMA center error: 12px
# step: 141, EMA radius error: 40px. EMA center error: 12px
# step: 142, EMA radius error: 38px. EMA center error: 12px
# step: 143, EMA radius error: 38px. EMA center error: 12px
# step: 144, EMA radius error: 37px. EMA center error: 12px
# step: 145, EMA radius error: 37px. EMA center error: 12px
# step: 146, EMA radius error: 36px. EMA center error: 12px
# step: 147, EMA radius error: 34px. EMA center error: 12px
# step: 148, EMA radius error: 33px. EMA center error: 11px
# step: 149, EMA radius error: 31px. EMA center error: 11px
# step: 150, EMA radius error: 32px. EMA center error: 11px
# step: 151, EMA radius error: 30px. EMA center error: 11px
# step: 152, EMA radius error: 30px. EMA center error: 11px
# step: 153, EMA radius error: 32px. EMA center error: 11px
# step: 154, EMA radius error: 31px. EMA center error: 11px
# step: 155, EMA radius error: 31px. EMA center error: 11px
# step: 156, EMA radius error: 29px. EMA center error: 11px
# step: 157, EMA radius error: 30px. EMA center error: 11px
# step: 158, EMA radius error: 30px. EMA center error: 11px
# step: 159, EMA radius error: 29px. EMA center error: 11px
# step: 160, EMA radius error: 28px. EMA center error: 10px
# step: 161, EMA radius error: 27px. EMA center error: 10px
# step: 162, EMA radius error: 28px. EMA center error: 10px
# step: 163, EMA radius error: 28px. EMA center error: 10px
# step: 164, EMA radius error: 27px. EMA center error: 10px
# step: 165, EMA radius error: 27px. EMA center error: 11px
# step: 166, EMA radius error: 30px. EMA center error: 10px
# step: 167, EMA radius error: 31px. EMA center error: 11px
# step: 168, EMA radius error: 35px. EMA center error: 11px
# step: 169, EMA radius error: 34px. EMA center error: 11px
# step: 170, EMA radius error: 33px. EMA center error: 11px
# step: 171, EMA radius error: 31px. EMA center error: 12px
# step: 172, EMA radius error: 33px. EMA center error: 12px
# step: 173, EMA radius error: 31px. EMA center error: 11px
# step: 174, EMA radius error: 30px. EMA center error: 11px
# step: 175, EMA radius error: 29px. EMA center error: 11px
# step: 176, EMA radius error: 31px. EMA center error: 11px
# step: 177, EMA radius error: 32px. EMA center error: 11px
# step: 178, EMA radius error: 30px. EMA center error: 11px
# step: 179, EMA radius error: 30px. EMA center error: 11px
# step: 180, EMA radius error: 29px. EMA center error: 11px
# step: 181, EMA radius error: 29px. EMA center error: 11px
# step: 182, EMA radius error: 30px. EMA center error: 11px
# step: 183, EMA radius error: 31px. EMA center error: 11px
# step: 184, EMA radius error: 30px. EMA center error: 11px
# step: 185, EMA radius error: 31px. EMA center error: 11px
# step: 186, EMA radius error: 31px. EMA center error: 11px
# step: 187, EMA radius error: 29px. EMA center error: 11px
# step: 188, EMA radius error: 28px. EMA center error: 11px
# step: 189, EMA radius error: 26px. EMA center error: 11px
# step: 190, EMA radius error: 27px. EMA center error: 11px
# step: 191, EMA radius error: 27px. EMA center error: 11px
# step: 192, EMA radius error: 27px. EMA center error: 10px
# step: 193, EMA radius error: 26px. EMA center error: 11px
# step: 194, EMA radius error: 25px. EMA center error: 11px
# step: 195, EMA radius error: 24px. EMA center error: 10px
# step: 196, EMA radius error: 23px. EMA center error: 10px
# step: 197, EMA radius error: 22px. EMA center error: 10px
# step: 198, EMA radius error: 22px. EMA center error: 10px
# step: 199, EMA radius error: 21px. EMA center error: 10px
# step: 200, EMA radius error: 20px. EMA center error: 10px
# step: 201, EMA radius error: 21px. EMA center error: 10px
# step: 202, EMA radius error: 21px. EMA center error: 10px
# step: 203, EMA radius error: 21px. EMA center error: 10px
# step: 204, EMA radius error: 20px. EMA center error: 10px
# step: 205, EMA radius error: 20px. EMA center error: 11px
# step: 206, EMA radius error: 19px. EMA center error: 11px
# step: 207, EMA radius error: 18px. EMA center error: 10px
# step: 208, EMA radius error: 19px. EMA center error: 10px
# step: 209, EMA radius error: 18px. EMA center error: 9px
# step: 210, EMA radius error: 17px. EMA center error: 9px
# step: 211, EMA radius error: 17px. EMA center error: 9px
# step: 212, EMA radius error: 16px. EMA center error: 9px
# step: 213, EMA radius error: 17px. EMA center error: 9px
# step: 214, EMA radius error: 20px. EMA center error: 9px
# step: 215, EMA radius error: 25px. EMA center error: 9px
# step: 216, EMA radius error: 26px. EMA center error: 9px
# step: 217, EMA radius error: 24px. EMA center error: 9px
# step: 218, EMA radius error: 23px. EMA center error: 10px
# step: 219, EMA radius error: 23px. EMA center error: 10px
# step: 220, EMA radius error: 23px. EMA center error: 10px
# step: 221, EMA radius error: 25px. EMA center error: 10px
# step: 222, EMA radius error: 25px. EMA center error: 10px
# step: 223, EMA radius error: 23px. EMA center error: 9px
# step: 224, EMA radius error: 23px. EMA center error: 9px
# step: 225, EMA radius error: 21px. EMA center error: 9px
# step: 226, EMA radius error: 21px. EMA center error: 9px
# step: 227, EMA radius error: 20px. EMA center error: 9px
# step: 228, EMA radius error: 20px. EMA center error: 9px
# step: 229, EMA radius error: 20px. EMA center error: 9px
# step: 230, EMA radius error: 19px. EMA center error: 9px
# step: 231, EMA radius error: 21px. EMA center error: 9px
# step: 232, EMA radius error: 20px. EMA center error: 9px
# step: 233, EMA radius error: 19px. EMA center error: 9px
# step: 234, EMA radius error: 18px. EMA center error: 9px
# step: 235, EMA radius error: 18px. EMA center error: 9px
# step: 236, EMA radius error: 17px. EMA center error: 9px
# step: 237, EMA radius error: 16px. EMA center error: 9px
# step: 238, EMA radius error: 17px. EMA center error: 9px
# step: 239, EMA radius error: 17px. EMA center error: 9px
# step: 240, EMA radius error: 17px. EMA center error: 9px
# step: 241, EMA radius error: 16px. EMA center error: 9px
# step: 242, EMA radius error: 16px. EMA center error: 9px
# step: 243, EMA radius error: 17px. EMA center error: 9px
# step: 244, EMA radius error: 16px. EMA center error: 9px
# step: 245, EMA radius error: 15px. EMA center error: 9px
# step: 246, EMA radius error: 15px. EMA center error: 9px
# step: 247, EMA radius error: 16px. EMA center error: 8px
# step: 248, EMA radius error: 16px. EMA center error: 8px
# step: 249, EMA radius error: 16px. EMA center error: 8px
# step: 250, EMA radius error: 16px. EMA center error: 8px
# step: 251, EMA radius error: 18px. EMA center error: 8px
# step: 252, EMA radius error: 18px. EMA center error: 8px
# step: 253, EMA radius error: 17px. EMA center error: 8px
# step: 254, EMA radius error: 18px. EMA center error: 8px
# step: 255, EMA radius error: 19px. EMA center error: 9px
# step: 256, EMA radius error: 19px. EMA center error: 9px
# step: 257, EMA radius error: 19px. EMA center error: 9px
# step: 258, EMA radius error: 20px. EMA center error: 9px
# step: 259, EMA radius error: 19px. EMA center error: 9px
# step: 260, EMA radius error: 21px. EMA center error: 9px
# step: 261, EMA radius error: 22px. EMA center error: 9px
# step: 262, EMA radius error: 21px. EMA center error: 9px
# step: 263, EMA radius error: 20px. EMA center error: 8px
# step: 264, EMA radius error: 20px. EMA center error: 9px
# step: 265, EMA radius error: 18px. EMA center error: 8px
# step: 266, EMA radius error: 18px. EMA center error: 8px
# step: 267, EMA radius error: 18px. EMA center error: 9px
# step: 268, EMA radius error: 17px. EMA center error: 9px
# step: 269, EMA radius error: 16px. EMA center error: 8px
# step: 270, EMA radius error: 16px. EMA center error: 8px
# step: 271, EMA radius error: 16px. EMA center error: 8px
# step: 272, EMA radius error: 17px. EMA center error: 8px
# step: 273, EMA radius error: 16px. EMA center error: 8px
# step: 274, EMA radius error: 15px. EMA center error: 8px
# step: 275, EMA radius error: 14px. EMA center error: 8px
# step: 276, EMA radius error: 15px. EMA center error: 8px
# step: 277, EMA radius error: 15px. EMA center error: 8px
# step: 278, EMA radius error: 14px. EMA center error: 8px
# step: 279, EMA radius error: 14px. EMA center error: 8px
# step: 280, EMA radius error: 14px. EMA center error: 8px
# step: 281, EMA radius error: 16px. EMA center error: 8px
# step: 282, EMA radius error: 18px. EMA center error: 8px
# step: 283, EMA radius error: 18px. EMA center error: 8px
# step: 284, EMA radius error: 18px. EMA center error: 8px
# step: 285, EMA radius error: 17px. EMA center error: 8px
# step: 286, EMA radius error: 16px. EMA center error: 8px
# step: 287, EMA radius error: 16px. EMA center error: 8px
# step: 288, EMA radius error: 16px. EMA center error: 8px
# step: 289, EMA radius error: 17px. EMA center error: 7px
# step: 290, EMA radius error: 16px. EMA center error: 7px
# step: 291, EMA radius error: 16px. EMA center error: 7px
# step: 292, EMA radius error: 15px. EMA center error: 7px
# step: 293, EMA radius error: 16px. EMA center error: 7px
# step: 294, EMA radius error: 15px. EMA center error: 7px
# step: 295, EMA radius error: 15px. EMA center error: 7px
# step: 296, EMA radius error: 14px. EMA center error: 7px
# step: 297, EMA radius error: 15px. EMA center error: 7px
# step: 298, EMA radius error: 16px. EMA center error: 7px
# step: 299, EMA radius error: 17px. EMA center error: 7px
# step: 300, EMA radius error: 18px. EMA center error: 7px
# step: 301, EMA radius error: 17px. EMA center error: 7px
# step: 302, EMA radius error: 16px. EMA center error: 8px
# step: 303, EMA radius error: 15px. EMA center error: 7px
# step: 304, EMA radius error: 15px. EMA center error: 7px
# step: 305, EMA radius error: 15px. EMA center error: 7px
# step: 306, EMA radius error: 16px. EMA center error: 7px
# step: 307, EMA radius error: 19px. EMA center error: 7px
# step: 308, EMA radius error: 17px. EMA center error: 7px
# step: 309, EMA radius error: 18px. EMA center error: 7px
# step: 310, EMA radius error: 17px. EMA center error: 7px
# step: 311, EMA radius error: 17px. EMA center error: 7px
# step: 312, EMA radius error: 17px. EMA center error: 7px
# step: 313, EMA radius error: 17px. EMA center error: 7px
# step: 314, EMA radius error: 16px. EMA center error: 7px
# step: 315, EMA radius error: 16px. EMA center error: 7px
# step: 316, EMA radius error: 15px. EMA center error: 7px
# step: 317, EMA radius error: 14px. EMA center error: 7px
# step: 318, EMA radius error: 14px. EMA center error: 7px
# step: 319, EMA radius error: 14px. EMA center error: 7px
# step: 320, EMA radius error: 13px. EMA center error: 7px
# step: 321, EMA radius error: 13px. EMA center error: 7px
# step: 322, EMA radius error: 14px. EMA center error: 7px
# step: 323, EMA radius error: 16px. EMA center error: 7px
# step: 324, EMA radius error: 16px. EMA center error: 7px
# step: 325, EMA radius error: 17px. EMA center error: 7px
# step: 326, EMA radius error: 16px. EMA center error: 7px
# step: 327, EMA radius error: 16px. EMA center error: 7px
# step: 328, EMA radius error: 15px. EMA center error: 7px
# step: 329, EMA radius error: 15px. EMA center error: 7px
# step: 330, EMA radius error: 14px. EMA center error: 7px
# step: 331, EMA radius error: 14px. EMA center error: 7px
# step: 332, EMA radius error: 15px. EMA center error: 6px
# step: 333, EMA radius error: 14px. EMA center error: 6px
# step: 334, EMA radius error: 13px. EMA center error: 6px
# step: 335, EMA radius error: 13px. EMA center error: 6px
# step: 336, EMA radius error: 12px. EMA center error: 6px
# step: 337, EMA radius error: 12px. EMA center error: 6px
# step: 338, EMA radius error: 12px. EMA center error: 6px
# step: 339, EMA radius error: 12px. EMA center error: 6px
# step: 340, EMA radius error: 11px. EMA center error: 6px
# step: 341, EMA radius error: 11px. EMA center error: 6px
# step: 342, EMA radius error: 11px. EMA center error: 6px
# step: 343, EMA radius error: 11px. EMA center error: 6px
# step: 344, EMA radius error: 11px. EMA center error: 6px
# step: 345, EMA radius error: 10px. EMA center error: 6px
# step: 346, EMA radius error: 11px. EMA center error: 6px
# step: 347, EMA radius error: 11px. EMA center error: 6px
# step: 348, EMA radius error: 12px. EMA center error: 7px
# step: 349, EMA radius error: 14px. EMA center error: 7px
# step: 350, EMA radius error: 14px. EMA center error: 7px
# step: 351, EMA radius error: 13px. EMA center error: 6px
# step: 352, EMA radius error: 12px. EMA center error: 6px
# step: 353, EMA radius error: 12px. EMA center error: 6px
# step: 354, EMA radius error: 11px. EMA center error: 6px
# step: 355, EMA radius error: 11px. EMA center error: 6px
# step: 356, EMA radius error: 10px. EMA center error: 6px
# step: 357, EMA radius error: 10px. EMA center error: 6px
# step: 358, EMA radius error: 10px. EMA center error: 6px
# step: 359, EMA radius error: 11px. EMA center error: 6px
# step: 360, EMA radius error: 11px. EMA center error: 6px
# step: 361, EMA radius error: 10px. EMA center error: 6px
# step: 362, EMA radius error: 10px. EMA center error: 6px
# step: 363, EMA radius error: 10px. EMA center error: 6px
# step: 364, EMA radius error: 11px. EMA center error: 6px
# step: 365, EMA radius error: 11px. EMA center error: 6px
# step: 366, EMA radius error: 11px. EMA center error: 6px
# step: 367, EMA radius error: 10px. EMA center error: 6px
# step: 368, EMA radius error: 10px. EMA center error: 6px
# step: 369, EMA radius error: 9px. EMA center error: 6px
# step: 370, EMA radius error: 9px. EMA center error: 6px
# step: 371, EMA radius error: 9px. EMA center error: 6px
# step: 372, EMA radius error: 8px. EMA center error: 6px
# step: 373, EMA radius error: 9px. EMA center error: 6px
# step: 374, EMA radius error: 9px. EMA center error: 6px
# step: 375, EMA radius error: 9px. EMA center error: 6px
# step: 376, EMA radius error: 9px. EMA center error: 6px
# step: 377, EMA radius error: 9px. EMA center error: 6px
# step: 378, EMA radius error: 11px. EMA center error: 6px
# step: 379, EMA radius error: 11px. EMA center error: 6px
# step: 380, EMA radius error: 12px. EMA center error: 7px
# step: 381, EMA radius error: 12px. EMA center error: 7px
# step: 382, EMA radius error: 12px. EMA center error: 7px
# step: 383, EMA radius error: 13px. EMA center error: 7px
# step: 384, EMA radius error: 13px. EMA center error: 7px
# step: 385, EMA radius error: 14px. EMA center error: 6px
# step: 386, EMA radius error: 13px. EMA center error: 6px
# step: 387, EMA radius error: 12px. EMA center error: 6px
# step: 388, EMA radius error: 11px. EMA center error: 6px
# step: 389, EMA radius error: 11px. EMA center error: 6px
# step: 390, EMA radius error: 11px. EMA center error: 6px
# step: 391, EMA radius error: 12px. EMA center error: 6px
# step: 392, EMA radius error: 11px. EMA center error: 6px
# step: 393, EMA radius error: 11px. EMA center error: 6px
# step: 394, EMA radius error: 11px. EMA center error: 6px
# step: 395, EMA radius error: 11px. EMA center error: 6px
# step: 396, EMA radius error: 12px. EMA center error: 7px
# step: 397, EMA radius error: 12px. EMA center error: 6px
# step: 398, EMA radius error: 11px. EMA center error: 6px
# step: 399, EMA radius error: 11px. EMA center error: 6px
# step: 400, EMA radius error: 11px. EMA center error: 6px
# step: 401, EMA radius error: 11px. EMA center error: 6px
# step: 402, EMA radius error: 11px. EMA center error: 6px
# step: 403, EMA radius error: 11px. EMA center error: 6px
# step: 404, EMA radius error: 10px. EMA center error: 6px
# step: 405, EMA radius error: 10px. EMA center error: 6px
# step: 406, EMA radius error: 10px. EMA center error: 6px
# step: 407, EMA radius error: 11px. EMA center error: 6px
# step: 408, EMA radius error: 11px. EMA center error: 6px
# step: 409, EMA radius error: 11px. EMA center error: 6px
# step: 410, EMA radius error: 11px. EMA center error: 6px
# step: 411, EMA radius error: 12px. EMA center error: 6px
# step: 412, EMA radius error: 12px. EMA center error: 6px
# step: 413, EMA radius error: 11px. EMA center error: 6px
# step: 414, EMA radius error: 11px. EMA center error: 6px
# step: 415, EMA radius error: 11px. EMA center error: 6px
# step: 416, EMA radius error: 11px. EMA center error: 6px
# step: 417, EMA radius error: 12px. EMA center error: 6px
# step: 418, EMA radius error: 11px. EMA center error: 6px
# step: 419, EMA radius error: 11px. EMA center error: 6px
# step: 420, EMA radius error: 12px. EMA center error: 6px
# step: 421, EMA radius error: 14px. EMA center error: 7px
# step: 422, EMA radius error: 13px. EMA center error: 7px
# step: 423, EMA radius error: 13px. EMA center error: 7px
# step: 424, EMA radius error: 13px. EMA center error: 6px
# step: 425, EMA radius error: 12px. EMA center error: 6px
# step: 426, EMA radius error: 11px. EMA center error: 6px
# step: 427, EMA radius error: 11px. EMA center error: 6px
# step: 428, EMA radius error: 10px. EMA center error: 6px
# step: 429, EMA radius error: 11px. EMA center error: 6px
# step: 430, EMA radius error: 10px. EMA center error: 6px
# step: 431, EMA radius error: 11px. EMA center error: 6px
# step: 432, EMA radius error: 11px. EMA center error: 6px
# step: 433, EMA radius error: 11px. EMA center error: 6px
# step: 434, EMA radius error: 11px. EMA center error: 6px
# step: 435, EMA radius error: 10px. EMA center error: 6px
# step: 436, EMA radius error: 10px. EMA center error: 6px
# step: 437, EMA radius error: 9px. EMA center error: 6px
# step: 438, EMA radius error: 9px. EMA center error: 5px
# step: 439, EMA radius error: 9px. EMA center error: 5px
# step: 440, EMA radius error: 10px. EMA center error: 5px
# step: 441, EMA radius error: 10px. EMA center error: 5px
# step: 442, EMA radius error: 9px. EMA center error: 6px
# step: 443, EMA radius error: 10px. EMA center error: 6px
# step: 444, EMA radius error: 11px. EMA center error: 6px
# step: 445, EMA radius error: 11px. EMA center error: 6px
# step: 446, EMA radius error: 10px. EMA center error: 6px
# step: 447, EMA radius error: 11px. EMA center error: 6px
# step: 448, EMA radius error: 12px. EMA center error: 5px
# step: 449, EMA radius error: 12px. EMA center error: 6px
# step: 450, EMA radius error: 11px. EMA center error: 6px
# step: 451, EMA radius error: 11px. EMA center error: 6px
# step: 452, EMA radius error: 10px. EMA center error: 6px
# step: 453, EMA radius error: 10px. EMA center error: 5px
# step: 454, EMA radius error: 10px. EMA center error: 5px
# step: 455, EMA radius error: 9px. EMA center error: 5px
# step: 456, EMA radius error: 9px. EMA center error: 5px
# step: 457, EMA radius error: 9px. EMA center error: 5px
# step: 458, EMA radius error: 9px. EMA center error: 5px
# step: 459, EMA radius error: 9px. EMA center error: 5px
# step: 460, EMA radius error: 9px. EMA center error: 6px
# step: 461, EMA radius error: 9px. EMA center error: 6px
# step: 462, EMA radius error: 9px. EMA center error: 6px
# step: 463, EMA radius error: 9px. EMA center error: 6px
# step: 464, EMA radius error: 9px. EMA center error: 6px
# step: 465, EMA radius error: 9px. EMA center error: 6px
# step: 466, EMA radius error: 10px. EMA center error: 6px
# step: 467, EMA radius error: 11px. EMA center error: 6px
# step: 468, EMA radius error: 10px. EMA center error: 6px
# step: 469, EMA radius error: 10px. EMA center error: 6px
# step: 470, EMA radius error: 9px. EMA center error: 6px
# step: 471, EMA radius error: 9px. EMA center error: 6px
# step: 472, EMA radius error: 9px. EMA center error: 6px
# step: 473, EMA radius error: 10px. EMA center error: 6px
# step: 474, EMA radius error: 11px. EMA center error: 6px
# step: 475, EMA radius error: 10px. EMA center error: 6px
# step: 476, EMA radius error: 10px. EMA center error: 6px
# step: 477, EMA radius error: 9px. EMA center error: 6px
# step: 478, EMA radius error: 9px. EMA center error: 5px
# step: 479, EMA radius error: 8px. EMA center error: 5px
# step: 480, EMA radius error: 8px. EMA center error: 5px
# step: 481, EMA radius error: 9px. EMA center error: 5px
# step: 482, EMA radius error: 9px. EMA center error: 5px
# step: 483, EMA radius error: 9px. EMA center error: 5px
# step: 484, EMA radius error: 9px. EMA center error: 5px
# step: 485, EMA radius error: 9px. EMA center error: 5px
# step: 486, EMA radius error: 8px. EMA center error: 5px
# step: 487, EMA radius error: 8px. EMA center error: 5px
# step: 488, EMA radius error: 8px. EMA center error: 5px
# step: 489, EMA radius error: 7px. EMA center error: 5px
# step: 490, EMA radius error: 8px. EMA center error: 5px
# step: 491, EMA radius error: 8px. EMA center error: 5px
# step: 492, EMA radius error: 8px. EMA center error: 5px
# step: 493, EMA radius error: 7px. EMA center error: 5px
# step: 494, EMA radius error: 7px. EMA center error: 5px
# step: 495, EMA radius error: 7px. EMA center error: 5px
# step: 496, EMA radius error: 7px. EMA center error: 5px
# step: 497, EMA radius error: 7px. EMA center error: 5px
# step: 498, EMA radius error: 6px. EMA center error: 5px
# step: 499, EMA radius error: 7px. EMA center error: 5px
# step: 500, EMA radius error: 7px. EMA center error: 5px
# step: 501, EMA radius error: 6px. EMA center error: 5px
# step: 502, EMA radius error: 6px. EMA center error: 5px
# step: 503, EMA radius error: 6px. EMA center error: 5px
# step: 504, EMA radius error: 7px. EMA center error: 6px
# step: 505, EMA radius error: 8px. EMA center error: 6px
# step: 506, EMA radius error: 8px. EMA center error: 6px
# step: 507, EMA radius error: 8px. EMA center error: 6px
# step: 508, EMA radius error: 8px. EMA center error: 6px
# step: 509, EMA radius error: 8px. EMA center error: 6px
# step: 510, EMA radius error: 8px. EMA center error: 6px
# step: 511, EMA radius error: 8px. EMA center error: 5px
# step: 512, EMA radius error: 8px. EMA center error: 5px
# step: 513, EMA radius error: 8px. EMA center error: 5px
# step: 514, EMA radius error: 7px. EMA center error: 5px
# step: 515, EMA radius error: 8px. EMA center error: 5px
# step: 516, EMA radius error: 8px. EMA center error: 5px
# step: 517, EMA radius error: 7px. EMA center error: 5px
# step: 518, EMA radius error: 8px. EMA center error: 6px
# step: 519, EMA radius error: 8px. EMA center error: 6px
# step: 520, EMA radius error: 8px. EMA center error: 6px
# step: 521, EMA radius error: 8px. EMA center error: 6px
# step: 522, EMA radius error: 8px. EMA center error: 6px
# step: 523, EMA radius error: 10px. EMA center error: 6px
# step: 524, EMA radius error: 9px. EMA center error: 5px
# step: 525, EMA radius error: 9px. EMA center error: 5px
# step: 526, EMA radius error: 8px. EMA center error: 5px
# step: 527, EMA radius error: 8px. EMA center error: 5px
# step: 528, EMA radius error: 8px. EMA center error: 5px
# step: 529, EMA radius error: 10px. EMA center error: 5px
# step: 530, EMA radius error: 12px. EMA center error: 6px
# step: 531, EMA radius error: 12px. EMA center error: 5px
# step: 532, EMA radius error: 11px. EMA center error: 5px
# step: 533, EMA radius error: 11px. EMA center error: 5px
# step: 534, EMA radius error: 10px. EMA center error: 5px
# step: 535, EMA radius error: 10px. EMA center error: 5px
# step: 536, EMA radius error: 11px. EMA center error: 5px
# step: 537, EMA radius error: 10px. EMA center error: 5px
# step: 538, EMA radius error: 10px. EMA center error: 5px
# step: 539, EMA radius error: 9px. EMA center error: 5px
# step: 540, EMA radius error: 9px. EMA center error: 5px
# step: 541, EMA radius error: 8px. EMA center error: 5px
# step: 542, EMA radius error: 8px. EMA center error: 5px
# step: 543, EMA radius error: 8px. EMA center error: 5px
# step: 544, EMA radius error: 8px. EMA center error: 5px
# step: 545, EMA radius error: 8px. EMA center error: 5px
# step: 546, EMA radius error: 8px. EMA center error: 5px
# step: 547, EMA radius error: 8px. EMA center error: 5px
# step: 548, EMA radius error: 7px. EMA center error: 5px
# step: 549, EMA radius error: 7px. EMA center error: 5px
# step: 550, EMA radius error: 7px. EMA center error: 5px
# step: 551, EMA radius error: 7px. EMA center error: 5px
# step: 552, EMA radius error: 7px. EMA center error: 5px
# step: 553, EMA radius error: 7px. EMA center error: 5px
# step: 554, EMA radius error: 7px. EMA center error: 5px
# step: 555, EMA radius error: 7px. EMA center error: 5px
# step: 556, EMA radius error: 7px. EMA center error: 5px
# step: 557, EMA radius error: 8px. EMA center error: 5px
# step: 558, EMA radius error: 7px. EMA center error: 5px
# step: 559, EMA radius error: 7px. EMA center error: 5px
# step: 560, EMA radius error: 7px. EMA center error: 5px
# step: 561, EMA radius error: 7px. EMA center error: 5px
# step: 562, EMA radius error: 7px. EMA center error: 5px
# step: 563, EMA radius error: 7px. EMA center error: 5px
# step: 564, EMA radius error: 7px. EMA center error: 5px
# step: 565, EMA radius error: 9px. EMA center error: 5px
# step: 566, EMA radius error: 8px. EMA center error: 5px
# step: 567, EMA radius error: 8px. EMA center error: 5px
# step: 568, EMA radius error: 8px. EMA center error: 5px
# step: 569, EMA radius error: 8px. EMA center error: 5px
# step: 570, EMA radius error: 8px. EMA center error: 5px
# step: 571, EMA radius error: 7px. EMA center error: 5px
# step: 572, EMA radius error: 8px. EMA center error: 5px
# step: 573, EMA radius error: 8px. EMA center error: 5px
# step: 574, EMA radius error: 8px. EMA center error: 6px
# step: 575, EMA radius error: 7px. EMA center error: 6px
# step: 576, EMA radius error: 9px. EMA center error: 6px
# step: 577, EMA radius error: 9px. EMA center error: 5px
# step: 578, EMA radius error: 8px. EMA center error: 5px
# step: 579, EMA radius error: 9px. EMA center error: 6px
# step: 580, EMA radius error: 8px. EMA center error: 5px
# step: 581, EMA radius error: 8px. EMA center error: 5px
# step: 582, EMA radius error: 8px. EMA center error: 5px
# step: 583, EMA radius error: 8px. EMA center error: 5px
# step: 584, EMA radius error: 8px. EMA center error: 5px
# step: 585, EMA radius error: 7px. EMA center error: 5px
# step: 586, EMA radius error: 8px. EMA center error: 5px
# step: 587, EMA radius error: 8px. EMA center error: 5px
# step: 588, EMA radius error: 7px. EMA center error: 5px
# step: 589, EMA radius error: 8px. EMA center error: 5px
# step: 590, EMA radius error: 9px. EMA center error: 5px
# step: 591, EMA radius error: 9px. EMA center error: 5px
# step: 592, EMA radius error: 9px. EMA center error: 5px
# step: 593, EMA radius error: 9px. EMA center error: 5px
# step: 594, EMA radius error: 9px. EMA center error: 5px
# step: 595, EMA radius error: 8px. EMA center error: 5px
# step: 596, EMA radius error: 8px. EMA center error: 5px
# step: 597, EMA radius error: 8px. EMA center error: 5px
# step: 598, EMA radius error: 7px. EMA center error: 5px
# step: 599, EMA radius error: 7px. EMA center error: 4px
# step: 600, EMA radius error: 7px. EMA center error: 4px
# step: 601, EMA radius error: 7px. EMA center error: 4px
# step: 602, EMA radius error: 6px. EMA center error: 4px
# step: 603, EMA radius error: 6px. EMA center error: 4px
# step: 604, EMA radius error: 6px. EMA center error: 4px
# step: 605, EMA radius error: 6px. EMA center error: 4px
# step: 606, EMA radius error: 6px. EMA center error: 4px
# step: 607, EMA radius error: 6px. EMA center error: 4px
# step: 608, EMA radius error: 6px. EMA center error: 4px
# step: 609, EMA radius error: 6px. EMA center error: 4px
# step: 610, EMA radius error: 6px. EMA center error: 4px
# step: 611, EMA radius error: 5px. EMA center error: 4px
# step: 612, EMA radius error: 5px. EMA center error: 4px
# step: 613, EMA radius error: 5px. EMA center error: 4px
# step: 614, EMA radius error: 5px. EMA center error: 4px
# step: 615, EMA radius error: 5px. EMA center error: 4px
# step: 616, EMA radius error: 7px. EMA center error: 5px
# step: 617, EMA radius error: 7px. EMA center error: 5px
# step: 618, EMA radius error: 7px. EMA center error: 5px
# step: 619, EMA radius error: 8px. EMA center error: 5px
# step: 620, EMA radius error: 8px. EMA center error: 5px
# step: 621, EMA radius error: 8px. EMA center error: 5px
# step: 622, EMA radius error: 7px. EMA center error: 4px
# step: 623, EMA radius error: 7px. EMA center error: 4px
# step: 624, EMA radius error: 7px. EMA center error: 5px
# step: 625, EMA radius error: 7px. EMA center error: 5px
# step: 626, EMA radius error: 8px. EMA center error: 5px
# step: 627, EMA radius error: 8px. EMA center error: 5px
# step: 628, EMA radius error: 7px. EMA center error: 5px
# step: 629, EMA radius error: 7px. EMA center error: 5px
# step: 630, EMA radius error: 6px. EMA center error: 5px
# step: 631, EMA radius error: 7px. EMA center error: 5px
# step: 632, EMA radius error: 6px. EMA center error: 5px
# step: 633, EMA radius error: 6px. EMA center error: 5px
# step: 634, EMA radius error: 6px. EMA center error: 5px
# step: 635, EMA radius error: 6px. EMA center error: 5px
# step: 636, EMA radius error: 6px. EMA center error: 4px
# step: 637, EMA radius error: 6px. EMA center error: 4px
# step: 638, EMA radius error: 6px. EMA center error: 4px
# step: 639, EMA radius error: 6px. EMA center error: 4px
# step: 640, EMA radius error: 6px. EMA center error: 4px
# step: 641, EMA radius error: 6px. EMA center error: 5px
# step: 642, EMA radius error: 6px. EMA center error: 5px
# step: 643, EMA radius error: 7px. EMA center error: 4px
# step: 644, EMA radius error: 7px. EMA center error: 4px
# step: 645, EMA radius error: 7px. EMA center error: 4px
# step: 646, EMA radius error: 7px. EMA center error: 4px
# step: 647, EMA radius error: 7px. EMA center error: 4px
# step: 648, EMA radius error: 7px. EMA center error: 4px
# step: 649, EMA radius error: 8px. EMA center error: 5px
# step: 650, EMA radius error: 9px. EMA center error: 5px
# step: 651, EMA radius error: 9px. EMA center error: 5px
# step: 652, EMA radius error: 9px. EMA center error: 5px
# step: 653, EMA radius error: 8px. EMA center error: 5px
# step: 654, EMA radius error: 8px. EMA center error: 5px
# step: 655, EMA radius error: 7px. EMA center error: 5px
# step: 656, EMA radius error: 7px. EMA center error: 5px
# step: 657, EMA radius error: 7px. EMA center error: 5px
# step: 658, EMA radius error: 7px. EMA center error: 4px
# step: 659, EMA radius error: 6px. EMA center error: 4px
# step: 660, EMA radius error: 6px. EMA center error: 4px
# step: 661, EMA radius error: 7px. EMA center error: 4px
# step: 662, EMA radius error: 6px. EMA center error: 4px
# step: 663, EMA radius error: 6px. EMA center error: 4px
# step: 664, EMA radius error: 6px. EMA center error: 4px
# step: 665, EMA radius error: 6px. EMA center error: 4px
# step: 666, EMA radius error: 7px. EMA center error: 4px
# step: 667, EMA radius error: 7px. EMA center error: 5px
# step: 668, EMA radius error: 7px. EMA center error: 4px
# step: 669, EMA radius error: 7px. EMA center error: 5px
# step: 670, EMA radius error: 7px. EMA center error: 4px
# step: 671, EMA radius error: 7px. EMA center error: 4px
# step: 672, EMA radius error: 7px. EMA center error: 5px
# step: 673, EMA radius error: 7px. EMA center error: 5px
# step: 674, EMA radius error: 6px. EMA center error: 5px
# step: 675, EMA radius error: 6px. EMA center error: 5px
# step: 676, EMA radius error: 6px. EMA center error: 5px
# step: 677, EMA radius error: 6px. EMA center error: 5px
# step: 678, EMA radius error: 7px. EMA center error: 5px
# step: 679, EMA radius error: 7px. EMA center error: 5px
# step: 680, EMA radius error: 7px. EMA center error: 5px
# step: 681, EMA radius error: 7px. EMA center error: 5px
# step: 682, EMA radius error: 7px. EMA center error: 5px
# step: 683, EMA radius error: 7px. EMA center error: 4px
# step: 684, EMA radius error: 7px. EMA center error: 4px
# step: 685, EMA radius error: 7px. EMA center error: 5px
# step: 686, EMA radius error: 6px. EMA center error: 5px
# step: 687, EMA radius error: 6px. EMA center error: 5px
# step: 688, EMA radius error: 6px. EMA center error: 4px
# step: 689, EMA radius error: 6px. EMA center error: 4px
# step: 690, EMA radius error: 5px. EMA center error: 4px
# step: 691, EMA radius error: 5px. EMA center error: 4px
# step: 692, EMA radius error: 5px. EMA center error: 4px
# step: 693, EMA radius error: 6px. EMA center error: 4px
# step: 694, EMA radius error: 6px. EMA center error: 5px
# step: 695, EMA radius error: 6px. EMA center error: 4px
# step: 696, EMA radius error: 6px. EMA center error: 4px
# step: 697, EMA radius error: 5px. EMA center error: 4px
# step: 698, EMA radius error: 5px. EMA center error: 4px
# step: 699, EMA radius error: 5px. EMA center error: 4px
# step: 700, EMA radius error: 5px. EMA center error: 4px
# step: 701, EMA radius error: 5px. EMA center error: 4px
# step: 702, EMA radius error: 5px. EMA center error: 4px
# step: 703, EMA radius error: 5px. EMA center error: 4px
# step: 704, EMA radius error: 5px. EMA center error: 4px
# step: 705, EMA radius error: 5px. EMA center error: 4px
# step: 706, EMA radius error: 5px. EMA center error: 4px
# step: 707, EMA radius error: 5px. EMA center error: 4px
# step: 708, EMA radius error: 5px. EMA center error: 4px
# step: 709, EMA radius error: 5px. EMA center error: 4px
# step: 710, EMA radius error: 5px. EMA center error: 4px
# step: 711, EMA radius error: 6px. EMA center error: 4px
# step: 712, EMA radius error: 6px. EMA center error: 4px
# step: 713, EMA radius error: 6px. EMA center error: 4px
# step: 714, EMA radius error: 5px. EMA center error: 4px
# step: 715, EMA radius error: 5px. EMA center error: 4px
# step: 716, EMA radius error: 5px. EMA center error: 4px
# step: 717, EMA radius error: 6px. EMA center error: 4px
# step: 718, EMA radius error: 6px. EMA center error: 4px
# step: 719, EMA radius error: 6px. EMA center error: 4px
# step: 720, EMA radius error: 6px. EMA center error: 4px
# step: 721, EMA radius error: 6px. EMA center error: 4px
# step: 722, EMA radius error: 6px. EMA center error: 4px
# step: 723, EMA radius error: 6px. EMA center error: 4px
# step: 724, EMA radius error: 6px. EMA center error: 4px
# step: 725, EMA radius error: 7px. EMA center error: 4px
# step: 726, EMA radius error: 6px. EMA center error: 4px
# step: 727, EMA radius error: 6px. EMA center error: 4px
# step: 728, EMA radius error: 7px. EMA center error: 5px
# step: 729, EMA radius error: 7px. EMA center error: 5px
# step: 730, EMA radius error: 7px. EMA center error: 5px
# step: 731, EMA radius error: 6px. EMA center error: 5px
# step: 732, EMA radius error: 6px. EMA center error: 5px
# step: 733, EMA radius error: 6px. EMA center error: 5px
# step: 734, EMA radius error: 6px. EMA center error: 5px
# step: 735, EMA radius error: 6px. EMA center error: 5px
# step: 736, EMA radius error: 6px. EMA center error: 5px
# step: 737, EMA radius error: 6px. EMA center error: 5px
# step: 738, EMA radius error: 6px. EMA center error: 5px
# step: 739, EMA radius error: 6px. EMA center error: 5px
# step: 740, EMA radius error: 6px. EMA center error: 5px
# step: 741, EMA radius error: 5px. EMA center error: 5px
# step: 742, EMA radius error: 5px. EMA center error: 5px
# step: 743, EMA radius error: 5px. EMA center error: 5px
# step: 744, EMA radius error: 5px. EMA center error: 4px
# step: 745, EMA radius error: 5px. EMA center error: 4px
# step: 746, EMA radius error: 6px. EMA center error: 5px
# step: 747, EMA radius error: 6px. EMA center error: 5px
# step: 748, EMA radius error: 5px. EMA center error: 4px
# step: 749, EMA radius error: 6px. EMA center error: 4px
# step: 750, EMA radius error: 6px. EMA center error: 4px
# step: 751, EMA radius error: 6px. EMA center error: 4px
# step: 752, EMA radius error: 6px. EMA center error: 4px
# step: 753, EMA radius error: 7px. EMA center error: 4px
# step: 754, EMA radius error: 7px. EMA center error: 4px
# step: 755, EMA radius error: 7px. EMA center error: 4px
# step: 756, EMA radius error: 8px. EMA center error: 5px
# step: 757, EMA radius error: 8px. EMA center error: 4px
# step: 758, EMA radius error: 8px. EMA center error: 4px
# step: 759, EMA radius error: 8px. EMA center error: 4px
# step: 760, EMA radius error: 7px. EMA center error: 4px
# step: 761, EMA radius error: 7px. EMA center error: 4px
# step: 762, EMA radius error: 7px. EMA center error: 4px
# step: 763, EMA radius error: 6px. EMA center error: 5px
# step: 764, EMA radius error: 7px. EMA center error: 5px
# step: 765, EMA radius error: 7px. EMA center error: 5px
# step: 766, EMA radius error: 9px. EMA center error: 5px
# step: 767, EMA radius error: 8px. EMA center error: 5px
# step: 768, EMA radius error: 8px. EMA center error: 5px
# step: 769, EMA radius error: 8px. EMA center error: 5px
# step: 770, EMA radius error: 7px. EMA center error: 5px
# step: 771, EMA radius error: 8px. EMA center error: 5px
# step: 772, EMA radius error: 7px. EMA center error: 5px
# step: 773, EMA radius error: 7px. EMA center error: 4px
# step: 774, EMA radius error: 6px. EMA center error: 4px
# step: 775, EMA radius error: 6px. EMA center error: 4px
# step: 776, EMA radius error: 6px. EMA center error: 4px
# step: 777, EMA radius error: 6px. EMA center error: 4px
# step: 778, EMA radius error: 6px. EMA center error: 4px
# step: 779, EMA radius error: 6px. EMA center error: 4px
# step: 780, EMA radius error: 6px. EMA center error: 4px
# step: 781, EMA radius error: 6px. EMA center error: 4px
# step: 782, EMA radius error: 6px. EMA center error: 4px
# step: 783, EMA radius error: 5px. EMA center error: 4px
# step: 784, EMA radius error: 6px. EMA center error: 5px
# step: 785, EMA radius error: 6px. EMA center error: 5px
# step: 786, EMA radius error: 6px. EMA center error: 4px
# step: 787, EMA radius error: 6px. EMA center error: 4px
# step: 788, EMA radius error: 5px. EMA center error: 5px
# step: 789, EMA radius error: 6px. EMA center error: 4px
# step: 790, EMA radius error: 5px. EMA center error: 4px
# step: 791, EMA radius error: 5px. EMA center error: 4px
# step: 792, EMA radius error: 5px. EMA center error: 4px
# step: 793, EMA radius error: 5px. EMA center error: 4px
# step: 794, EMA radius error: 5px. EMA center error: 4px
# step: 795, EMA radius error: 5px. EMA center error: 4px
# step: 796, EMA radius error: 5px. EMA center error: 4px
# step: 797, EMA radius error: 5px. EMA center error: 4px
# step: 798, EMA radius error: 5px. EMA center error: 4px
# step: 799, EMA radius error: 5px. EMA center error: 4px
# step: 800, EMA radius error: 6px. EMA center error: 4px
# step: 801, EMA radius error: 5px. EMA center error: 4px
# step: 802, EMA radius error: 5px. EMA center error: 4px
# step: 803, EMA radius error: 5px. EMA center error: 4px
# step: 804, EMA radius error: 4px. EMA center error: 4px
# step: 805, EMA radius error: 5px. EMA center error: 4px
# step: 806, EMA radius error: 5px. EMA center error: 5px
# step: 807, EMA radius error: 5px. EMA center error: 4px
# step: 808, EMA radius error: 6px. EMA center error: 4px
# step: 809, EMA radius error: 6px. EMA center error: 4px
# step: 810, EMA radius error: 5px. EMA center error: 4px
# step: 811, EMA radius error: 5px. EMA center error: 4px
# step: 812, EMA radius error: 5px. EMA center error: 4px
# step: 813, EMA radius error: 5px. EMA center error: 4px
# step: 814, EMA radius error: 5px. EMA center error: 4px
# step: 815, EMA radius error: 5px. EMA center error: 4px
# step: 816, EMA radius error: 5px. EMA center error: 4px
# step: 817, EMA radius error: 5px. EMA center error: 4px
# step: 818, EMA radius error: 4px. EMA center error: 4px
# step: 819, EMA radius error: 4px. EMA center error: 4px
# step: 820, EMA radius error: 4px. EMA center error: 4px
# step: 821, EMA radius error: 5px. EMA center error: 4px
# step: 822, EMA radius error: 4px. EMA center error: 4px
# step: 823, EMA radius error: 4px. EMA center error: 4px
# step: 824, EMA radius error: 5px. EMA center error: 4px
# step: 825, EMA radius error: 6px. EMA center error: 4px
# step: 826, EMA radius error: 6px. EMA center error: 4px
# step: 827, EMA radius error: 6px. EMA center error: 4px
# step: 828, EMA radius error: 6px. EMA center error: 4px
# step: 829, EMA radius error: 6px. EMA center error: 4px
# step: 830, EMA radius error: 5px. EMA center error: 4px
# step: 831, EMA radius error: 5px. EMA center error: 4px
# step: 832, EMA radius error: 5px. EMA center error: 4px
# step: 833, EMA radius error: 5px. EMA center error: 4px
# step: 834, EMA radius error: 5px. EMA center error: 4px
# step: 835, EMA radius error: 5px. EMA center error: 4px
# step: 836, EMA radius error: 5px. EMA center error: 4px
# step: 837, EMA radius error: 5px. EMA center error: 4px
# step: 838, EMA radius error: 5px. EMA center error: 4px
# step: 839, EMA radius error: 5px. EMA center error: 4px
# step: 840, EMA radius error: 4px. EMA center error: 4px
# step: 841, EMA radius error: 4px. EMA center error: 4px
# step: 842, EMA radius error: 5px. EMA center error: 4px
# step: 843, EMA radius error: 5px. EMA center error: 4px
# step: 844, EMA radius error: 5px. EMA center error: 4px
# step: 845, EMA radius error: 5px. EMA center error: 4px
# step: 846, EMA radius error: 5px. EMA center error: 4px
# step: 847, EMA radius error: 5px. EMA center error: 4px
# step: 848, EMA radius error: 5px. EMA center error: 4px
# step: 849, EMA radius error: 5px. EMA center error: 4px
# step: 850, EMA radius error: 5px. EMA center error: 4px
# step: 851, EMA radius error: 5px. EMA center error: 4px
# step: 852, EMA radius error: 5px. EMA center error: 4px
# step: 853, EMA radius error: 5px. EMA center error: 4px
# step: 854, EMA radius error: 6px. EMA center error: 4px
# step: 855, EMA radius error: 6px. EMA center error: 4px
# step: 856, EMA radius error: 6px. EMA center error: 4px
# step: 857, EMA radius error: 5px. EMA center error: 4px
# step: 858, EMA radius error: 6px. EMA center error: 4px
# step: 859, EMA radius error: 6px. EMA center error: 4px
# step: 860, EMA radius error: 5px. EMA center error: 4px
# step: 861, EMA radius error: 5px. EMA center error: 4px
# step: 862, EMA radius error: 5px. EMA center error: 4px
# step: 863, EMA radius error: 5px. EMA center error: 4px
# step: 864, EMA radius error: 4px. EMA center error: 4px
# step: 865, EMA radius error: 4px. EMA center error: 4px
# step: 866, EMA radius error: 4px. EMA center error: 4px
# step: 867, EMA radius error: 5px. EMA center error: 4px
# step: 868, EMA radius error: 5px. EMA center error: 4px
# step: 869, EMA radius error: 5px. EMA center error: 4px
# step: 870, EMA radius error: 5px. EMA center error: 4px
# step: 871, EMA radius error: 6px. EMA center error: 4px
# step: 872, EMA radius error: 5px. EMA center error: 4px
# step: 873, EMA radius error: 5px. EMA center error: 4px
# step: 874, EMA radius error: 5px. EMA center error: 4px
# step: 875, EMA radius error: 5px. EMA center error: 4px
# step: 876, EMA radius error: 4px. EMA center error: 4px
# step: 877, EMA radius error: 4px. EMA center error: 4px
# step: 878, EMA radius error: 4px. EMA center error: 4px
# step: 879, EMA radius error: 5px. EMA center error: 4px
# step: 880, EMA radius error: 5px. EMA center error: 4px
# step: 881, EMA radius error: 6px. EMA center error: 4px
# step: 882, EMA radius error: 6px. EMA center error: 4px
# step: 883, EMA radius error: 6px. EMA center error: 4px
# step: 884, EMA radius error: 5px. EMA center error: 4px
# step: 885, EMA radius error: 5px. EMA center error: 4px
# step: 886, EMA radius error: 5px. EMA center error: 4px
# step: 887, EMA radius error: 5px. EMA center error: 4px
# step: 888, EMA radius error: 5px. EMA center error: 4px
# step: 889, EMA radius error: 5px. EMA center error: 4px
# step: 890, EMA radius error: 5px. EMA center error: 4px
# step: 891, EMA radius error: 4px. EMA center error: 4px
# step: 892, EMA radius error: 4px. EMA center error: 4px
# step: 893, EMA radius error: 4px. EMA center error: 4px
# step: 894, EMA radius error: 4px. EMA center error: 4px
# step: 895, EMA radius error: 4px. EMA center error: 4px
# step: 896, EMA radius error: 4px. EMA center error: 4px
# step: 897, EMA radius error: 5px. EMA center error: 4px
# step: 898, EMA radius error: 4px. EMA center error: 4px
# step: 899, EMA radius error: 4px. EMA center error: 4px
# step: 900, EMA radius error: 4px. EMA center error: 4px
# step: 901, EMA radius error: 4px. EMA center error: 4px
# step: 902, EMA radius error: 4px. EMA center error: 4px
# step: 903, EMA radius error: 4px. EMA center error: 4px
# step: 904, EMA radius error: 4px. EMA center error: 4px
# step: 905, EMA radius error: 4px. EMA center error: 4px
# step: 906, EMA radius error: 4px. EMA center error: 4px
# step: 907, EMA radius error: 4px. EMA center error: 4px
# step: 908, EMA radius error: 4px. EMA center error: 4px
# step: 909, EMA radius error: 4px. EMA center error: 4px
# step: 910, EMA radius error: 4px. EMA center error: 4px
# step: 911, EMA radius error: 4px. EMA center error: 4px
# step: 912, EMA radius error: 4px. EMA center error: 4px
# step: 913, EMA radius error: 4px. EMA center error: 4px
# step: 914, EMA radius error: 4px. EMA center error: 4px
# step: 915, EMA radius error: 5px. EMA center error: 4px
# step: 916, EMA radius error: 5px. EMA center error: 4px
# step: 917, EMA radius error: 6px. EMA center error: 4px
# step: 918, EMA radius error: 6px. EMA center error: 4px
# step: 919, EMA radius error: 6px. EMA center error: 4px
# step: 920, EMA radius error: 5px. EMA center error: 4px
# step: 921, EMA radius error: 6px. EMA center error: 4px
# step: 922, EMA radius error: 6px. EMA center error: 4px
# step: 923, EMA radius error: 5px. EMA center error: 4px
# step: 924, EMA radius error: 5px. EMA center error: 4px
# step: 925, EMA radius error: 5px. EMA center error: 3px
# step: 926, EMA radius error: 5px. EMA center error: 4px
# step: 927, EMA radius error: 6px. EMA center error: 4px
# step: 928, EMA radius error: 5px. EMA center error: 3px
# step: 929, EMA radius error: 5px. EMA center error: 3px
# step: 930, EMA radius error: 5px. EMA center error: 4px
# step: 931, EMA radius error: 6px. EMA center error: 4px
# step: 932, EMA radius error: 6px. EMA center error: 4px
# step: 933, EMA radius error: 6px. EMA center error: 4px
# step: 934, EMA radius error: 6px. EMA center error: 4px
# step: 935, EMA radius error: 6px. EMA center error: 4px
# step: 936, EMA radius error: 6px. EMA center error: 4px
# step: 937, EMA radius error: 6px. EMA center error: 4px
# step: 938, EMA radius error: 6px. EMA center error: 4px
# step: 939, EMA radius error: 6px. EMA center error: 4px
# step: 940, EMA radius error: 5px. EMA center error: 4px
# step: 941, EMA radius error: 5px. EMA center error: 4px
# step: 942, EMA radius error: 5px. EMA center error: 4px
# step: 943, EMA radius error: 5px. EMA center error: 4px
# step: 944, EMA radius error: 5px. EMA center error: 4px
# step: 945, EMA radius error: 5px. EMA center error: 3px
# step: 946, EMA radius error: 4px. EMA center error: 3px
# step: 947, EMA radius error: 5px. EMA center error: 3px
# step: 948, EMA radius error: 5px. EMA center error: 4px
# step: 949, EMA radius error: 6px. EMA center error: 4px
# step: 950, EMA radius error: 6px. EMA center error: 4px
# step: 951, EMA radius error: 6px. EMA center error: 4px
# step: 952, EMA radius error: 6px. EMA center error: 4px
# step: 953, EMA radius error: 5px. EMA center error: 4px
# step: 954, EMA radius error: 5px. EMA center error: 4px
# step: 955, EMA radius error: 5px. EMA center error: 4px
# step: 956, EMA radius error: 5px. EMA center error: 4px
# step: 957, EMA radius error: 5px. EMA center error: 4px
# step: 958, EMA radius error: 5px. EMA center error: 4px
# step: 959, EMA radius error: 5px. EMA center error: 4px
# step: 960, EMA radius error: 5px. EMA center error: 4px
# step: 961, EMA radius error: 5px. EMA center error: 4px
# step: 962, EMA radius error: 4px. EMA center error: 4px
# step: 963, EMA radius error: 4px. EMA center error: 4px
# step: 964, EMA radius error: 4px. EMA center error: 4px
# step: 965, EMA radius error: 4px. EMA center error: 4px
# step: 966, EMA radius error: 4px. EMA center error: 4px
# step: 967, EMA radius error: 4px. EMA center error: 4px
# step: 968, EMA radius error: 4px. EMA center error: 4px
# step: 969, EMA radius error: 4px. EMA center error: 4px
# step: 970, EMA radius error: 4px. EMA center error: 4px
# step: 971, EMA radius error: 4px. EMA center error: 3px
# step: 972, EMA radius error: 4px. EMA center error: 3px
# step: 973, EMA radius error: 4px. EMA center error: 4px
# step: 974, EMA radius error: 5px. EMA center error: 4px
# step: 975, EMA radius error: 5px. EMA center error: 4px
# step: 976, EMA radius error: 6px. EMA center error: 4px
# step: 977, EMA radius error: 6px. EMA center error: 4px
# step: 978, EMA radius error: 7px. EMA center error: 4px
# step: 979, EMA radius error: 6px. EMA center error: 4px
# step: 980, EMA radius error: 7px. EMA center error: 4px
# step: 981, EMA radius error: 6px. EMA center error: 4px
# step: 982, EMA radius error: 6px. EMA center error: 4px
# step: 983, EMA radius error: 6px. EMA center error: 4px
# step: 984, EMA radius error: 5px. EMA center error: 4px
# step: 985, EMA radius error: 5px. EMA center error: 4px
# step: 986, EMA radius error: 5px. EMA center error: 4px
# step: 987, EMA radius error: 5px. EMA center error: 4px
# step: 988, EMA radius error: 5px. EMA center error: 4px
# step: 989, EMA radius error: 4px. EMA center error: 4px
# step: 990, EMA radius error: 4px. EMA center error: 4px
# step: 991, EMA radius error: 4px. EMA center error: 4px
# step: 992, EMA radius error: 4px. EMA center error: 4px
# step: 993, EMA radius error: 4px. EMA center error: 4px
# step: 994, EMA radius error: 4px. EMA center error: 4px
# step: 995, EMA radius error: 3px. EMA center error: 4px
# step: 996, EMA radius error: 3px. EMA center error: 4px
# step: 997, EMA radius error: 3px. EMA center error: 4px
# step: 998, EMA radius error: 3px. EMA center error: 4px
# step: 999, EMA radius error: 3px. EMA center error: 4px
# Complete!

# %% [markdown]
# # Visualizing the Results!

# %%
sample_batch = np.asarray(latest_results["samples"])
prediction   = latest_results["prediction"]
actual       = latest_results["actual"].transpose()

# Extract and round
xp, yp, rp      = [np.rint(p).astype(np.int32) for p in prediction]
xa, ya, ra      = [np.rint(a).astype(np.int32) for a in actual]

result_display = []


# Add the prediction and the actual to the dataset
for i, sample in enumerate(sample_batch):
    draw_circle(sample, xa[i], ya[i], ra[i],  DARKNESS, CIRCLE_WIDTH)
    draw_circle(sample, xp[i], yp[i], rp[i], -DARKNESS, CIRCLE_WIDTH)  # The prediction will appear bright
    result_display.append(sample)


plot_dataset(np.array(result_display))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img2103f3ccea1e46dcbfcef63e7b8704a0">
#     <br>
#     <input id="_anim_slider2103f3ccea1e46dcbfcef63e7b8704a0" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim2103f3ccea1e46dcbfcef63e7b8704a0.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim2103f3ccea1e46dcbfcef63e7b8704a0.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim2103f3ccea1e46dcbfcef63e7b8704a0.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim2103f3ccea1e46dcbfcef63e7b8704a0.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim2103f3ccea1e46dcbfcef63e7b8704a0.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim2103f3ccea1e46dcbfcef63e7b8704a0.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim2103f3ccea1e46dcbfcef63e7b8704a0.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim2103f3ccea1e46dcbfcef63e7b8704a0.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim2103f3ccea1e46dcbfcef63e7b8704a0.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim2103f3ccea1e46dcbfcef63e7b8704a0.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select2103f3ccea1e46dcbfcef63e7b8704a0" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img2103f3ccea1e46dcbfcef63e7b8704a0";
#     var slider_id = "_anim_slider2103f3ccea1e46dcbfcef63e7b8704a0";
#     var loop_select_id = "_anim_loop_select2103f3ccea1e46dcbfcef63e7b8704a0";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvNQv5yAAAIABJREFUeJzs3WuMZPd55/df3e+Xrr739Fw4nBE5\
# oixLNG3Zu5ZCkct1rBhiImkZGoZ3HEnhbuBFLDkBpHX8RovApr2xYiE2kkygLAjBkbASDNKQbXrX\
# 4jqB7CWYWZBCVrzNkDPT0/dLdVd1dde9Ki8ECusV+3nOf2aoGQHfzzvp33zq1Dn/c+rpYvP3xMbj\
# 8VgAAAAAIonf7gMAAAAAfpTQQAMAAAABaKABAACAADTQAAAAQAAaaAAAACAADTQAAAAQgAYaAAAA\
# CEADDQAAAASggQYAAAAC0EADAAAAAWigAQAAgAA00AAAAEAAGmgAAAAgAA00AAAAEIAGGgAAAAhA\
# Aw0AAAAEoIEGAAAAAtBAAwAAAAFooAEAAIAANNAAAABAABpoAAAAIAANNAAAABCABhoAAAAIQAMN\
# AAAABKCBBgAAAALQQAMAAAABaKABAACAADTQAAAAQAAaaAAAACAADTQAAAAQgAYaAAAACEADDQAA\
# AASggQYAAAAC0EADAAAAAWigAQAAgAA00AAAAEAAGmgAAAAgAA00AAAAEIAGGgAAAAhAAw0AAAAE\
# oIEGAAAAAtBAAwAAAAFooAEAAIAANNAAAABAABpoAAAAIAANNAAAABCABhoAAAAIQAMNAAAABKCB\
# BgAAAALQQAMAAAABaKABAACAADTQAAAAQAAaaAAAACAADTQAAAAQgAYaAAAACEADDQAAAASggQYA\
# AAAC0EADAAAAAWigAQAAgAA00AAAAEAAGmgAAAAgAA00AAAAEIAGGgAAAAhAAw0AAAAEoIEGAAAA\
# AtBAAwAAAAFooAEAAIAANNAAAABAABpoAAAAIAANNAAAABCABhoAAAAIQAMNAAAABKCBBgAAAALQ\
# QAMAAAABaKABAACAADTQAAAAQAAaaAAAACAADTQAAAAQgAYaAAAACEADDQAAAASggQYAAAAC0EAD\
# AAAAAWigAQAAgAA00AAAAEAAGmgAAAAgQPJ2HwCkVCWv9GzlyPXBIOHWSCaG5vpwFOF3pdjYXB6P\
# Ym6JeNyuMYpQI+b9iHOckpR2zsdo7B/HYGif91TSfo0or5OIjdwavYF9m8YinI/R0L7+8YR/HN7r\
# +GdUGrrnw38v3v2QjHBdvIMdDCLcL857iXIc3n059k+Huw+j3PvetU3FI+xT537x7klJ6vRS9g9E\
# 2B+Z1MBcH0fYqb2+/8z1JJ17KspxSBE2gMN7Fe+Z/b0a9s90+34r4b1OOsL94u2PVNK+9pL/XI9H\
# 2Ove/TCIcM+5nw0RjsN/fvh7rNjoant72/05/CAa6HfIs88+q1/7tV/TcDjUpz/9aX3+858/8mfT\
# sxW95385f+T6xtbRzfVbpib3zfVGK+fWSDgP/G7b+XCTVCx1zPXWftY/jqR9HMmU/6A9Udu1j6OX\
# cWtsNwvm+rFaw61x2LfPWTnddWtc2Zw011Np/0Oj3bLfb6FsXzdJSjkNkNcwSFKr7RxHtufW2Nkp\
# muuTky23hvfhtL1nv4YkjXr2B/HUdNOt0Tyw74d+z39Ez0/Z+7DZ8fe6d21ni/45XW7Yz6nFin+/\
# vHpt3lyPp/w9dvfclrneG/nN8fWtCXN9PPQbk8mafc76Eb4Y8Zq5KA1Swmlcy1n/3k86v+i/uTHl\
# 1sjl7WfdieqeW+PlJXt/LM7az31JWq+XzfViwT8fcyX783brwH9+dJxfOso5/ziabfv50e34n9nV\
# f/60+zN4e/wJxztgOBzqV3/1V/Xnf/7nevnll/XVr35VL7/88u0+LAAAANwCNNDvgBdeeEFnzpzR\
# 6dOnlU6n9fjjj+uZZ5653YcFAACAW4AG+h2wsrKi48ePf/9/Ly4uamVl5TYeEQAAA

# %% [markdown]
# Based on our model result, it is not doing very well. There is room for improvement!
#
# For potential cryto-grant, fork the project, PR with your model with 500 runs of training. If you can improve it, do it!

# %% [markdown]
# # Thank you!
#
# That was a lot of info!
# Thank you for your time and hopefully this will help you on your path.
#
# For your troubles, here's a flower:
# ![](https://i.imgur.com/i6wAoY9.png)
# <p style="text-align:center">AI generated flower, orchestration by Dave MacDonald</p>

# %% [markdown]
# # Connect with the Toronto AI community
#
# <img src="https://cdn.worldvectorlogo.com/logos/slack-1.svg" style="display:inline;width: 30px;padding-right:1em;"/> Come join us on our Slack Channel!  (Here is the <a href="https://join.slack.com/t/toronto-ai/shared_invite/enQtMjE5NTM5MzY3NTU0LTQ0ZDIyM2ZlZDYwMmRjY2I2NTEyMjZjYzJkNzljZTI1ZWRiMDkzYjUyZjRkMTc5ZDM0OGJmZjdmNzM5NDM5Zjk">Invite link</a> if you haven't signed up yet)
#
# <img src="https://cdn.worldvectorlogo.com/logos/meetup.svg" style="display:inline;width: 30px;padding-right:1em;"/> Come to our next event - join our [Meetup Group](https://www.meetup.com/Toronto-AI/)
#
# <img src="https://i.imgur.com/KGSBbUe.png" style="display:inline;width:30px;padding-right:1em;3"/> NEO tips <span style='font-size:.75em'>AdLG9AyRtCMSeAy98rmkkos7uFU6i7fLgd</span>
#
#
# Toronto AI website: [http://torontoai.org/](http://torontoai.org/)<br>
# We're also on Facebook and Twitter
# <br><br>
# Thank you, see you soon!

# %% [markdown]
# ## Additional Resources
#
# * [Deep Learning Book](http://www.deeplearningbook.org/)
